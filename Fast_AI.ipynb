# %%
# !pip install fastai==0.7.0

# %%
# !pip install --upgrade ipython
# Out:
# ...
#     100% |████████████████████████████████| 778kB 24.6MB/s
# ...
#     100% |████████████████████████████████| 337kB 29.2MB/s
# ...
# google-colab 1.0.0 has requirement ipython~=5.5.0, but you'll have ipython 7.4.0 which is incompatible.
# ...
#   Found existing installation: prompt-toolkit 1.0.15
#     Uninstalling prompt-toolkit-1.0.15:
#       Successfully uninstalled prompt-toolkit-1.0.15
#   Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
# ...

# %%
from fastai import *

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.structured import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %%
? display

# %%
# !unzip 'Train.zip'
# Out:
# Archive:  Train.zip
#   inflating: Train.csv

# %%
# !ls
# Out:
# sample_data  Train.csv	Train.zip

# %%
# !head Train.csv
# Out:
# SalesID,SalePrice,MachineID,ModelID,datasource,auctioneerID,YearMade,MachineHoursCurrentMeter,UsageBand,saledate,fiModelDesc,fiBaseModel,fiSecondaryDesc,fiModelSeries,fiModelDescriptor,ProductSize,fiProductClassDesc,state,ProductGroup,ProductGroupDesc,Drive_System,Enclosure,Forks,Pad_Type,Ride_Control,Stick,Transmission,Turbocharged,Blade_Extension,Blade_Width,Enclosure_Type,Engine_Horsepower,Hydraulics,Pushblock,Ripper,Scarifier,Tip_Control,Tire_Size,Coupler,Coupler_System,Grouser_Tracks,Hydraulics_Flow,Track_Type,Undercarriage_Pad_Width,Stick_Length,Thumb,Pattern_Changer,Grouser_Type,Backhoe_Mounting,Blade_Type,Travel_Controls,Differential_Type,Steering_Controls
# 1139246,66000,999089,3157,121,3,2004,68,Low,11/16/2006 0:00,521D,521,D,,,,Wheel Loader - 110.0 to 120.0 Horsepower,Alabama,WL,Wheel Loader,,EROPS w AC,None or Unspecified,,None or Unspecified,,,,,,,,2 Valve,,,,,None or Unspecified,None or Unspecified,,,,,,,,,,,,,Standard,Conventional
# ...

# %%
df_raw = pd.read_csv('Train.csv',low_memory = False,parse_dates = ["saledate"])

# %%
df_raw.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate        ...         \
# 0                      68.0       Low 2006-11-16        ...
# 1                    4640.0       Low 2004-03-26        ...
# 2                    2838.0      High 2004-02-26        ...
# 3                    3486.0      High 2011-05-19        ...
# 4                     722.0    Medium 2009-07-23        ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# ...

# %%
def display_all(df):
  with pd.option_context("display.max_rows",1000):
    with pd.option_context("display.max_columns",1000):
      display(df)

# %%
display_all(df_raw.tail().transpose())
# Out:
#                                                                      401120  \
# SalesID                                                             6333336
# SalePrice                                                             10500
# MachineID                                                           1840702
# ModelID                                                               21439
# datasource                                                              149
# auctioneerID                                                              1
# YearMade                                                               2005
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                2011-11-02 00:00:00
# fiModelDesc                                                           35NX2
# ...

# %%
df_raw.SalePrice = np.log(df_raw.SalePrice)
df_raw.SalePrice
# Out:
# 0         11.097410
# 1         10.950807
# 2          9.210340
# 3         10.558414
# 4          9.305651
# 5         10.184900
# 6          9.952278
# 7         10.203592
# 8          9.975808
# 9         11.082143
# 10        10.085809
# 11        10.021271
# 12        10.491274
# 13        10.325482
# 14        10.239960
# 15         9.852194
# 16         9.510445
# 17         9.159047
# 18         9.433484
# 19         9.350102
# 20        10.621327
# 21        10.448715
# 22        10.165852
# 23        11.198215
# 24        10.404263
# 25         9.433484
# 26         9.648595
# 27        10.878047
# 28        10.736397
# 29        11.396392
#             ...
# 401095     9.259131
# 401096     9.210340
# 401097     9.047821
# 401098     9.259131
# 401099     9.305651
# 401100     9.259131
# 401101     9.210340
# 401102     9.259131
# 401103     9.433484
# 401104     9.259131
# 401105     9.210340
# 401106     9.259131
# 401107     9.433484
# 401108     9.259131
# ...

# %%
# ?RandomForestRegressor

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(df_raw.drop('SalePrice',axis=1),df_raw.SalePrice)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6dd7566c4b95> in <module>()
#       1 m = RandomForestRegressor(n_jobs=-1)
# ----> 2 m.fit(df_raw.drop('SalePrice',axis=1),df_raw.SalePrice)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ...

# %%
df_raw.saledate
# Out:
# 0        2006-11-16
# 1        2004-03-26
# 2        2004-02-26
# 3        2011-05-19
# 4        2009-07-23
# 5        2008-12-18
# 6        2004-08-26
# 7        2005-11-17
# 8        2009-08-27
# 9        2007-08-09
# 10       2008-08-21
# 11       2006-08-24
# 12       2005-10-20
# 13       2006-01-26
# 14       2006-01-03
# 15       2006-11-16
# 16       2007-06-14
# 17       2010-01-28
# 18       2006-03-09
# 19       2005-11-17
# 20       2006-05-18
# 21       2006-10-19
# 22       2007-10-25
# 23       2006-10-19
# 24       2004-05-20
# 25       2006-03-09
# 26       2006-03-09
# 27       2007-02-22
# 28       2007-08-09
# 29       2006-06-01
#             ...
# 401095   2011-12-14
# 401096   2011-09-15
# 401097   2011-10-28
# 401098   2011-08-16
# 401099   2011-12-14
# 401100   2011-08-16
# 401101   2011-12-14
# 401102   2011-08-16
# 401103   2011-09-15
# 401104   2011-08-16
# 401105   2011-10-25
# 401106   2011-08-16
# 401107   2011-09-15
# 401108   2011-08-16
# ...

# %%
add_datepart
# Out:
# <function fastai.structured.add_datepart>

# %%
??add_datepart

# %%
fld = 'saledate'

# %%
add_datepart(df_raw,fld)

# %%
display_all(df_raw.head())
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246  11.097410     999089     3157         121           3.0      2004
# 1  1139248  10.950807     117657       77         121           3.0      1996
# 2  1139249   9.210340     434808     7009         121           3.0      2001
# 3  1139251  10.558414    1026470      332         121           3.0      2001
# 4  1139253   9.305651    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand fiModelDesc fiBaseModel fiSecondaryDesc  \
# 0                      68.0       Low        521D         521               D
# 1                    4640.0       Low      950FII         950               F
# 2                    2838.0      High         226         226             NaN
# 3                    3486.0      High    PC120-6E       PC120             NaN
# 4                     722.0    Medium        S175        S175             NaN
#
# ...

# %%
df_raw.saleYear.head()
# Out:
# 0    2006
# 1    2004
# 2    2004
# 3    2011
# 4    2009
# Name: saleYear, dtype: int64

# %%
df_raw.columns
# Out:
# Index(['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
#        'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'UsageBand',
#        'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc', 'fiModelSeries',
#        'fiModelDescriptor', 'ProductSize', 'fiProductClassDesc', 'state',
#        'ProductGroup', 'ProductGroupDesc', 'Drive_System', 'Enclosure',
#        'Forks', 'Pad_Type', 'Ride_Control', 'Stick', 'Transmission',
#        'Turbocharged', 'Blade_Extension', 'Blade_Width', 'Enclosure_Type',
#        'Engine_Horsepower', 'Hydraulics', 'Pushblock', 'Ripper', 'Scarifier',
#        'Tip_Control', 'Tire_Size', 'Coupler', 'Coupler_System',
#        'Grouser_Tracks', 'Hydraulics_Flow', 'Track_Type',
#        'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb', 'Pattern_Changer',
#        'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type', 'Travel_Controls',
#        'Differential_Type', 'Steering_Controls', 'saleYear', 'saleMonth',
# ...

# %%
??add_datepart

# %%
??df_raw.items()

# %%
??train_cats

# %%
display_all(df_raw.head())
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246  11.097410     999089     3157         121           3.0      2004
# 1  1139248  10.950807     117657       77         121           3.0      1996
# 2  1139249   9.210340     434808     7009         121           3.0      2001
# 3  1139251  10.558414    1026470      332         121           3.0      2001
# 4  1139253   9.305651    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand fiModelDesc fiBaseModel fiSecondaryDesc  \
# 0                      68.0       Low        521D         521               D
# 1                    4640.0       Low      950FII         950               F
# 2                    2838.0      High         226         226             NaN
# 3                    3486.0      High    PC120-6E       PC120             NaN
# 4                     722.0    Medium        S175        S175             NaN
#
# ...

# %%
train_cats(df_raw)
display_all(df_raw.head())
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246  11.097410     999089     3157         121           3.0      2004
# 1  1139248  10.950807     117657       77         121           3.0      1996
# 2  1139249   9.210340     434808     7009         121           3.0      2001
# 3  1139251  10.558414    1026470      332         121           3.0      2001
# 4  1139253   9.305651    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand fiModelDesc fiBaseModel fiSecondaryDesc  \
# 0                      68.0       Low        521D         521               D
# 1                    4640.0       Low      950FII         950               F
# 2                    2838.0      High         226         226             NaN
# 3                    3486.0      High    PC120-6E       PC120             NaN
# 4                     722.0    Medium        S175        S175             NaN
#
# ...

# %%
df_raw.UsageBand.head()
# Out:
# 0       Low
# 1       Low
# 2      High
# 3      High
# 4    Medium
# Name: UsageBand, dtype: category
# Categories (3, object): [High < Low < Medium]

# %%
df_raw.UsageBand.cat.categories
# Out:
# Index(['High', 'Low', 'Medium'], dtype='object')

# %% [markdown]
# High is stored as 0 , Low as 1 and Medium as 2.

# %%
??apply_cats

# %%
df_raw.UsageBand.cat.set_categories(['High','Medium','Low'],ordered=True,inplace=True)

# %%
df_raw.UsageBand.cat.categories
# Out:
# Index(['High', 'Medium', 'Low'], dtype='object')

# %%
df_raw.UsageBand.cat.codes

# %%
os.makedirs('temp',exist_ok = True)
df_raw.to_feather('temp/raw')

# %%
df_raw.to_csv('temp/raw.csv')

# %%
display_all(df_raw.isnull().sum().sort_index()/len(df_raw))
# Out:
# Backhoe_Mounting            0.803872
# Blade_Extension             0.937129
# Blade_Type                  0.800977
# Blade_Width                 0.937129
# Coupler                     0.466620
# Coupler_System              0.891660
# Differential_Type           0.826959
# Drive_System                0.739829
# Enclosure                   0.000810
# Enclosure_Type              0.937129
# Engine_Horsepower           0.937129
# Forks                       0.521154
# Grouser_Tracks              0.891899
# Grouser_Type                0.752813
# Hydraulics                  0.200823
# Hydraulics_Flow             0.891899
# MachineHoursCurrentMeter    0.644089
# MachineID                   0.000000
# ModelID                     0.000000
# Pad_Type                    0.802720
# Pattern_Changer             0.752651
# ProductGroup                0.000000
# ProductGroupDesc            0.000000
# ProductSize                 0.525460
# Pushblock                   0.937129
# ...

# %%
??proc_df

# %%
??fix_missing

# %%
df,y,nas = proc_df(df_raw,'SalePrice')

# %%
print(len(df),len(y))
# Out:
# 401125 401125

# %% [markdown]
# So, what proc_df does is , numericalizes categorical values by adding 1 and then, replace missing values with medians and creates extra columns with _na which indicates 0 or 1 based on wheather the particular value in the column was missing or not..

# %%
m = RandomForestRegressor(n_jobs = -1)
m.fit(df,y)
m.score(df,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9830798502447077

# %%
#how well it performs on validation data

# %%
train_df = df[12000:]

# %%
train_df.head()
# Out:
#        SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 12000  1178478    1045738    26204         121           3.0      1000
# 12001  1178484    1004675     9580         121           3.0      2006
# 12002  1178486    1025434     9580         121           3.0      2004
# 12003  1178488    1013274     8988         121           3.0      1000
# 12004  1178493    1012492     3546         121           3.0      1994
#
#        MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  \
# 12000                    8066.0          3          944          295
# 12001                    1441.0          1         4458         1675
# 12002                    3659.0          1         4458         1675
# 12003                    2436.0          3         2021          683
# 12004                   10090.0          2          756          248
#
#                   ...               saleDayofyear  saleIs_month_end  \
# ...

# %%
test_df = df[:12000]

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(train_df,y[12000:])
m.score(train_df,y[12000:])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9829912768609886

# %%
m.score(test_df,y[:12000])
# Out:
# 0.8734867815542887

# %%
preds = m.predict(test_df)
rmse = math.sqrt(((preds-y[:12000])**2).mean())

# %%
print(rmse)
# Out:
# 0.2470344825595415
